# %%
# Import necessary libraries
from Node_Records_tools import NodeRecords

# %%
# Import example Node Records csv-file
nodelog = NodeRecords(r"C:\Users\Käyttäjä\Documents\GitHub\Trajectory-Log-and-Node-Records-tools\Examples\example_raw_Node_Records_datafile.csv")
# Out:
# Data from 'C:\Users\Käyttäjä\Documents\GitHub\Trajectory-Log-and-Node-Records-tools\Examples\example_raw_Node_Records_datafile.csv' has been cleaned.

# %%
nodelog.to_dataframe()
# Out:
#                          Time   AExp1  APrim1   ASec1    AExp2   APrim2  \
# 0     2024/04/19 07:21:09:173  -2.032  -1.976  -1.955  -15.187  -15.187
# 1     2024/04/19 07:21:09:183  -2.058  -2.001  -1.969  -15.187  -15.187
# 2     2024/04/19 07:21:09:193  -2.083  -2.027  -1.984  -15.187  -15.187
# 3     2024/04/19 07:21:09:203  -2.109  -2.052  -2.032  -15.187  -15.187
# 4     2024/04/19 07:21:09:213  -2.134  -2.078  -2.042  -15.187  -15.187
# ...                       ...     ...     ...     ...      ...      ...
# 3995  2024/04/19 07:22:04:673     0.0     0.0   0.024      0.0      0.0
# 3996  2024/04/19 07:22:04:684     0.0     0.0   0.024      0.0      0.0
# 3997  2024/04/19 07:22:04:694     0.0     0.0   0.024      0.0      0.0
# 3998  2024/04/19 07:22:04:704     0.0     0.0   0.024      0.0      0.0
# 3999  2024/04/19 07:22:04:713     0.0     0.0   0.024      0.0      0.0
#
#         ASec2   AExp3  APrim3   ASec3  ...  BSec57   BExp58  BPrim58   BSec58  \
# ...
